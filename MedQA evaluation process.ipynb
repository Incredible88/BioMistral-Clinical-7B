# %% [markdown]
# # MedQA evaluation process
# This notebook shows the evaluation process after SFT with MedQA.

# %%
from transformers import AutoTokenizer, DataCollatorForLanguageModeling,TrainingArguments,Trainer
import pandas as pd
from transformers import AutoModelForCausalLM
from datasets import Dataset

# %% [markdown]
# ## Load the based model and the SFT model with LORA

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

base_model_id = "./BioMistral-7B"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    base_model_id,  # Mistral, same as before
    quantization_config=bnb_config,  # Same quantization config as before
    device_map="auto",
    trust_remote_code=True,
)

tokenizer = AutoTokenizer.from_pretrained(
    base_model_id,
    add_bos_token=True,
    trust_remote_code=True,
)

# %%
from peft import PeftModel

ft_model = PeftModel.from_pretrained(model, "biomistral-biomistral-7B-MedmcQA-SFT/checkpoint-10000")

# %% [markdown]
# ## Make the few-shot prompting for QA evaluation
# Test the prompt for both base model and sft model

# %%
model_device = next(model.parameters()).device
#  Telling the model how to answer the question
eval_prompt = """
### Question:
Best prognostic factor for head injury is ？

### Option：
 'A': 'A.Glasgow coma scale',
 'B': 'B.Age',
 'C': 'C.Mode of injury',
 'D': 'D.CT'

### Answer:
'A': 'A.Glasgow coma scale'

### Question:
Congenital hydrocele is best treated by ?

### Option：
 'A': 'Eversion of sac',
 'B': 'Excision of sac',
 'C': "Lord's procedure",
 'D': 'Herniotomy',

### Answer:

"""

model_input = tokenizer(eval_prompt, return_tensors="pt").to(model_device)

model.eval()

with torch.no_grad():
    # generate output using base model
    output = model.generate(**model_input, max_new_tokens=300)
    # decode output
    answer = tokenizer.decode(output[0], skip_special_tokens=True)
    print(answer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ### Question:
# Best prognostic factor for head injury is ？
#
# ### Option：
#  'A': 'A.Glasgow coma scale',
#  'B': 'B.Age',
#  'C': 'C.Mode of injury',
#  'D': 'D.CT'
#
# ### Answer:
# 'A': 'A.Glasgow coma scale'
#
# ### Question:
# Congenital hydrocele is best treated by ?
#
# ### Option：
#  'A': 'Eversion of sac',
#  'B': 'Excision of sac',
#  'C': "Lord's procedure",
#  'D': 'Herniotomy',
#
# ### Answer:
#
# 'B': 'Excision of sac'

# %%
eval_prompt = """
Choose the right choice:

### Question:
Best prognostic factor for head injury is ？

### Option：
 'A': 'A.Glasgow coma scale',
 'B': 'B.Age',
 'C': 'C.Mode of injury',
 'D': 'D.CT'

### Answer:
'A': 'A.Glasgow coma scale'

### Question:
Secondary amyloidosis occurs in ?

### Option：
 'A': 'Chronic osteomyelitis',
 'B': 'Rheumatoid ahritis',
 'C': 'Leprosy',
 'D': 'All'

### Answer:
"""

model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")

# generate output using ft_model
with torch.no_grad():
    print(tokenizer.decode(ft_model.generate(**model_input, max_new_tokens=10)[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Choose the right choice:
#
# ### Question:
# Best prognostic factor for head injury is ？
#
# ### Option：
#  'A': 'A.Glasgow coma scale',
#  'B': 'B.Age',
#  'C': 'C.Mode of injury',
#  'D': 'D.CT'
#
# ### Answer:
# 'A': 'A.Glasgow coma scale'
#
# ### Question:
# Secondary amyloidosis occurs in ?
#
# ### Option：
#  'A': 'Chronic osteomyelitis',
#  'B': 'Rheumatoid ahritis',
#  'C': 'Leprosy',
#  'D': 'All'
#
# ### Answer:
# 'C': 'Leprosy',

# %% [markdown]
# ## Loading a separate test dataset

# %%
import pandas as pd
df = pd.read_csv('train_dataset.csv')[:100]
df.tail()
# Out:
#                                              question  \
# 95  Which of the following is/are true of blunt re...
# 96  All of the following can lead to increased Int...
# 97  Chronic lymphoedema of the limb is predisposed...
# 98                  Secondary amyloidosis occurs in ?
# 99                 Lahsal classification is used for:
#
#                                                     A  \
# 95  Blunt renal trauma and penetrating renal injur...
# 96                                         Meningitis
# 97                             Thickening of the skin
# 98                              Chronic osteomyelitis
# 99                               Cleft lip and palate
#
#                                                     B  \
# 95  Blunt renal trauma must be evaluated by contra...
# 96                            Subarachnoid Hemorrhage
# 97                   Recurrent soft tissue infections
# 98                                 Rheumatoid ahritis
# 99                                      Tumor staging
#
#                                                     C  \
# 95  Blunt renal trauma requires exploration only w...
# 96                                Subdural hemorrhage
# 97                                  Marjolin' s ulcer
# 98                                            Leprosy
# 99          Neurological assessment of trauma patient
#
#                                                     D cop  \
# 95  Any kidney fractured by blunt renal trauma mus...   B
# 96                                           Migraine   C
# 97                                            Sarcoma   B
# 98                                                All   C
# 99                                  None of the above   D
#
#                                                Answer
# 95  Blunt renal trauma must be evaluated by contra...
# 96                                Subdural hemorrhage
# 97                   Recurrent soft tissue infections
# 98                                            Leprosy
# 99                                  None of the above

# %% [markdown]
# ## Build the evaluation process
# Iterate using the model to QA the test dataset to generate answers, and record the answers for final accuracy

# %%
from tqdm import tqdm
import pandas as pd

# Read the CSV file
df = pd.read_csv('test_dataset.csv')
model_device = next(model.parameters()).device

# Define the evaluation function
def evaluate_question(question, options, model, tokenizer, model_device):
    option_str = '\n'.join([f"'{k}': '{v}'" for k, v in options.items()])
    eval_prompt = f"""
    ### Question:
    Best prognostic factor for head injury is ?

    ### Options:
     'A': 'A.Glasgow coma scale',
     'B': 'B.Age',
     'C': 'C.Mode of injury',
     'D': 'D.CT'

    ### Answer:
    'A': 'A.Glasgow coma scale'

    ### Question:
    {question} ?

    ### Options:
    \n{option_str}

    ### Answer:
    """
    model_input = tokenizer(eval_prompt, return_tensors="pt").to(model_device)
    with torch.no_grad():
        output = model.generate(**model_input, max_new_tokens=20)
        answer = tokenizer.decode(output[0], skip_special_tokens=True)
        # Parse the generated answer
        generated_answer = answer.split("### Answer:")[1].strip().split("'")[1]
    return generated_answer

# Iterate over the dataset and evaluate each question
results = []
num_correct = 0
tqdm_pbar = tqdm(total=len(df), desc="Evaluating")
for index, row in df.iterrows():

    question = row['question']
    options = {
        'A': row['A'],
        'B': row['B'],
        'C': row['C'],
        'D': row['D']
    }
    correct_answer = row['cop']
    generated_answer = evaluate_question(question, options, model, tokenizer, model_device=next(model.parameters()).device)

    # Check if the answer is correct
    is_correct = "Yes" if generated_answer == correct_answer else "No"
    results.append({
        'Question': question,
        'Correct Answer': correct_answer,
        'Generated Answer': generated_answer,
        'Is Correct': is_correct
    })
    if is_correct == "Yes":
        num_correct += 1
    tqdm_pbar.update(1)  # Update the progress bar

tqdm_pbar.close()  # Close the progress bar after completion

# Calculate accuracy
accuracy = num_correct / len(df) * 100
# Out:
# Evaluating:   0%|          | 0/1000 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   0%|          | 1/1000 [00:00<11:09,  1.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   0%|          | 2/1000 [00:02<18:04,  1.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   0%|          | 3/1000 [00:02<15:21,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   0%|          | 4/1000 [00:03<14:03,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   0%|          | 5/1000 [00:04<13:43,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   1%|          | 6/1000 [00:05<13:09,  1.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   1%|          | 7/1000 [00:06<14:28,  1.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   1%|          | 8/1000 [00:06<13:42,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:   1%|          |
  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 956/1000 [14:09<00:37,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 957/1000 [14:10<00:39,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 958/1000 [14:10<00:36,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 959/1000 [14:12<00:37,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 960/1000 [14:13<00:41,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 961/1000 [14:14<00:36,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▌| 962/1000 [14:15<00:39,  1.05s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▋| 963/1000 [14:16<00:35,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▋| 964/1000 [14:16<00:32,  1.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  96%|█████████▋| 965/1000 [14:17<00:33,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 966/1000 [14:18<00:31,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 967/1000 [14:19<00:30,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 968/1000 [14:20<00:26,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 969/1000 [14:21<00:30,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 970/1000 [14:22<00:32,  1.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 971/1000 [14:24<00:33,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 972/1000 [14:24<00:27,  1.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 973/1000 [14:25<00:23,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  97%|█████████▋| 974/1000 [14:26<00:24,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 975/1000 [14:27<00:26,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 976/1000 [14:28<00:24,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 977/1000 [14:29<00:22,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 978/1000 [14:30<00:20,  1.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 979/1000 [14:31<00:19,  1.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 980/1000 [14:32<00:18,  1.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 981/1000 [14:33<00:16,  1.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 982/1000 [14:33<00:14,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 983/1000 [14:34<00:14,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 984/1000 [14:35<00:13,  1.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  98%|█████████▊| 985/1000 [14:36<00:12,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▊| 986/1000 [14:37<00:13,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▊| 987/1000 [14:38<00:12,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 988/1000 [14:39<00:11,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 989/1000 [14:40<00:10,  1.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 990/1000 [14:41<00:09,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 991/1000 [14:42<00:08,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 992/1000 [14:43<00:08,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 993/1000 [14:44<00:07,  1.04s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating:  99%|█████████▉| 994/1000 [14:45<00:05,  1.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating: 100%|█████████▉| 995/1000 [14:46<00:04,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating: 100%|█████████▉| 996/1000 [14:46<00:03,  1.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating: 100%|█████████▉| 997/1000 [14:48<00:02,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating: 100%|█████████▉| 998/1000 [14:48<00:01,  1.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating: 100%|█████████▉| 999/1000 [14:49<00:00,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#
# Evaluating: 100%|██████████| 1000/1000 [14:50<00:00,  1.12it/s]

# %%
accuracy
# Out:
# 43.5

# %%
# Look the result
results[:10]
# Out:
# [{'Question': 'All of the following are surgical options for morbid obesity except -',
#   'Correct Answer': 'C',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'A 60 yr old chronic smoker presents with painless gross hematuria of 1 day duration. Investigation of choice to know the cause of hematuria',
#   'Correct Answer': 'C',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'An Isograft indicates transfer of tissues between -',
#   'Correct Answer': 'B',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'Which of the following muscle is not a hybrid muscle',
#   'Correct Answer': 'A',
#   'Generated Answer': 'A',
#   'Is Correct': 'Yes'},
#  {'Question': 'Delayed union of fracture of a bone follo-wing a surgical treatment may be due to',
#   'Correct Answer': 'C',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'During extraction of the upper first molar, the mesio buccal root is missing and is suspected to have been pushed into the maxillary sinus.\nThe best position for the patient immediately after the incident is',
#   'Correct Answer': 'D',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'Potter syndrome is not assoiated with',
#   'Correct Answer': 'D',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'All are true about Cancer breast, except:',
#   'Correct Answer': 'C',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'Congenital hydrocele is best treated by',
#   'Correct Answer': 'C',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'},
#  {'Question': 'A 19 year old female presents with pain in the neck for 5 days. She is not able to wear tie for her job because of neck pain. H/O fatigue and lethargy for 10 days. She had flu like symptoms 20 days ago which resolved spontaneously. BP 110/80 mmHg, Pulse 48/min. Extremities are cold and dry. Neck is very tender. ECG normal. TSH is elevated. ESR 30 mm/hr. Next appropriate step',
#   'Correct Answer': 'B',
#   'Generated Answer': 'A',
#   'Is Correct': 'No'}]
